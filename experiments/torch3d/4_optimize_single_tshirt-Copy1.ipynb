# %%
import os
import torch
import matplotlib.pyplot as plt
import xml.dom.minidom
from skimage.io import imread
from skimage import img_as_ubyte
from pyrr import Matrix44, Vector4, Vector3
import pyrr

# Util function for loading meshes
from pytorch3d.io import load_objs_as_meshes

# Data structures and functions for rendering
from pytorch3d.structures import Meshes, Textures
from pytorch3d.renderer import (
    OpenGLPerspectiveCameras, 
    PointLights, 
    DirectionalLights, 
    Materials, 
    RasterizationSettings, 
    MeshRenderer, 
    MeshRasterizer,  
    TexturedSoftPhongShader,
    HardPhongShader
)
from pytorch3d.renderer.cameras import look_at_view_transform

from torch_openpose.body import Body
from torch_openpose import util
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import cm

from tqdm import tqdm
import torch.nn as nn
import imageio
import cv2
import copy

import wandb

# add path for demo utils functions 
import sys
import os
sys.path.append(os.path.abspath(''))
import pytorch3d

# %%
def transform_node_to_matrix(node):
    model_matrix = np.identity(4)
    for child in reversed(node.childNodes):
        if child.nodeName == "translate":
            x = float(child.getAttribute('x'))
            y = float(child.getAttribute('y'))
            z = float(child.getAttribute('z'))
            z *= -1
            translate_vec = Vector3([x, y, z])
            trans_matrix = np.transpose(pyrr.matrix44.create_from_translation(translate_vec))
            model_matrix = np.matmul(model_matrix, trans_matrix)
        if child.nodeName == "scale":
            scale = float(child.getAttribute('value'))
            scale_vec = Vector3([scale, scale, scale])
            scale_matrix = np.transpose(pyrr.matrix44.create_from_scale(scale_vec))
            model_matrix = np.matmul(model_matrix, scale_matrix)
            
    return model_matrix

def transform_node_to_R_T(node):
    eye = node.getAttribute('origin').split(',')
    eye = [float(i) for i in eye]
    at = node.getAttribute('target').split(',')
    at = [float(i) for i in at]
    up = node.getAttribute('up').split(',')
    up = [float(i) for i in up]
    
    R, T = look_at_view_transform(
        eye=[eye], 
        at=[at], 
        up=[up]
    )
    return R, T

def load_shape(shape):
    if shape is None:
        return None
    device = torch.device("cuda:0")
    char_filename_node = shape.getElementsByTagName('string')[0]
    char_filename = char_filename_node.getAttribute('value')
    obj_filename = os.path.join(DATA_ROOT, char_filename)
    mesh = load_objs_as_meshes([obj_filename], device=device)
    verticies, faces = mesh.get_mesh_verts_faces(0)
    texture = mesh.textures.clone() if mesh.textures is not None else None
    
    
    
    transform_node = shape.getElementsByTagName('transform')
    if len(transform_node) == 0:
        verticies[:, 2] *= -1
        return verticies, faces, texture
    # apply transform
    transform_node = transform_node[0]
    model_matrix =  transform_node_to_matrix(transform_node)
    model_matrix = torch.from_numpy(model_matrix).cuda().double() 
    
    # make coordiantes homegenos
    new_row = torch.ones(1, verticies.shape[0], device=device)
    vetrices_homo = torch.cat((verticies.t(), new_row)).double() 
    
    # transform
    vetrices_world = torch.chain_matmul(model_matrix, vetrices_homo).t()[:, :3]
    return vetrices_world.float(), faces, texture

def mitsuba_scene_to_torch_3d(master_scene):
    device = torch.device("cuda:0")
    master_doc = xml.dom.minidom.parse(master_scene)
    camera = master_doc.getElementsByTagName('sensor')[0]
    camera_transform = camera.getElementsByTagName('transform')[0]
    R, T = transform_node_to_R_T(camera_transform.getElementsByTagName('lookat')[0])
    # TODO figure out how to set camera params
    cameras = OpenGLPerspectiveCameras(
        znear=0.1,
        zfar=1000,
        fov=15,
        degrees=True,
        device=device, 
        R=R, 
        T=T
    )
    
    
    character = None
    tshirt = None
    ground = None
    
    shapes = master_doc.getElementsByTagName('shape')
    for i in range(len(shapes)):
        if shapes[i].getAttribute("id") == 'character':
            character = shapes[i]
        if shapes[i].getAttribute("id") == 'simulated':
            tshirt = shapes[i]
        if shapes[i].getAttribute("id") == 'place.000000':
            ground = shapes[i]
    
    tshirt_vetrices, tshirt_faces, tshirt_texture = load_shape(tshirt)
    character_vetrices, character_faces, character_texture = load_shape(character)
    ground_vetrices, ground_faces, ground_texture = load_shape(ground)
    
    texTshirt = torch.ones_like(tshirt_vetrices).cuda()
    tex2 = torch.ones_like(character_vetrices).cuda()
    tex3 = torch.ones_like(ground_vetrices).cuda()
    texTshirt[:, 1:] *= 0.0  # red
    # person
    tex2[:, 0] *= 0.88
    tex2[:, 1] *= 0.67
    tex2[:, 2] *= 0.41
    #tex3 [:, :2] *= 0.3  # blue
    tex = torch.cat([texTshirt, tex2, tex3])[None]  # (1, 204, 3)
    textures = Textures(verts_rgb=tex.cuda())
    
    verts = torch.cat([tshirt_vetrices,character_vetrices, ground_vetrices]).cuda()  #(204, 3)
    
    character_faces = character_faces + tshirt_vetrices.shape[0]  
    ground_faces = ground_faces  + character_vetrices.shape[0] + tshirt_vetrices.shape[0]  
    faces = torch.cat([tshirt_faces, character_faces, ground_faces]).cuda()  
    mesh = Meshes(verts=[verts], faces=[faces], textures=textures)
    
    optmization_input = {
        "texTshirt": texTshirt,
        "texOther": torch.cat([tex2, tex3]),
        "verticies": verts, 
        "faces": faces
    }
        
    return mesh, cameras, optmization_input

class Model(nn.Module):
    def __init__(self, texTshirt, texOther, verticies, faces, renderer, body_estimation):
        super().__init__()
        self.device = torch.device("cuda:0")
        self.renderer = renderer
        self.texOther = texOther
        self.verticies = verticies
        self.faces = faces
        self.body_estimation = body_estimation
        self.cur_mesh = None
        
        self.texTshirt = nn.Parameter(
            torch.zeros_like(texTshirt).to(self.device)
        )
        
        ## loss functions
        self.objective = torch.nn.MSELoss()
        self.zero_heatmap = torch.zeros((1, 19, 64, 64), device=self.device)
        self.zero_paf = torch.zeros((1, 38, 64, 64), device=self.device)

    def forward(self):
        tex = torch.cat([self.texTshirt, self.texOther])[None]  # (1, 204, 3)
        textures = Textures(verts_rgb=tex.cuda())
        
        self.cur_mesh = Meshes(verts=[self.verticies], faces=[self.faces], textures=textures)
        images = self.renderer(self.cur_mesh)
        
        #
        body_input = (images[..., :3] - 0.5).permute((0, 3, 1, 2)).float()
        paf, heat = self.body_estimation.model(body_input)
        
        ob_val_heat = self.objective(heat, self.zero_heatmap)
        ob_val_paf = self.objective(paf, self.zero_paf)
        
        # Calculate the silhouette loss
        loss = ob_val_heat + ob_val_paf
        return loss, images
    
def get_body_image_from_mesh(cur_mesh, body_estimation, renderer):
    images = renderer(cur_mesh)
        
    rendering_torch_input = (images[..., :3] - 0.5).permute((0, 3, 1, 2)).float()
    
    heatmap_avg, paf_avg = body_estimation.compute_heatmap_paf_avg(rendering_torch_input, ORIG_SHAPE)
    candidate, subset = body_estimation.get_pose(heatmap_avg, paf_avg, ORIG_SHAPE)
    rendering_torch_np =  images[0, ..., :3].detach().squeeze().cpu().numpy()
    canvas = copy.deepcopy(rendering_torch_np)
    canvas = util.draw_bodypose(canvas, candidate, subset)
    
    return canvas, candidate, subset, heatmap_avg, paf_avg

def wandb_init(name):
    run = wandb.init(
        project = "mts_tshirt_single", 
        reinit = True,
        name = name,
        config={
            "steps": 100,
            "learning_rate": 0.2
        }
    )
    
    return run

# %%
ORIG_SHAPE = (512, 512, 3)
DATA_ROOT = 'data/radek'
# Setup
device = torch.device("cuda:0")
torch.cuda.set_device(device)

# Set paths
master_scene = 'data/radek/00008_mesh88_animated.xml'
mesh, cameras, optmization_input = mitsuba_scene_to_torch_3d(master_scene)

# %%
raster_settings = RasterizationSettings(image_size=512, blur_radius=0.0, faces_per_pixel=1)
lights = PointLights(device=device, location=[[0.0, 0.0, 3.0]])

renderer = MeshRenderer(
    rasterizer=MeshRasterizer(
        cameras=cameras, 
        raster_settings=raster_settings
    ), 
    shader=HardPhongShader(
        device=device, 
        cameras=cameras, 
        lights=lights
    )
)

# %%
image = renderer(mesh)   # (1, H, W, 4)
ref_image = cv2.imread('data/radek/out.png')
ref_image = cv2.cvtColor(ref_image, cv2.COLOR_BGR2RGB)

fig = plt.figure(figsize=(20, 10))
ax = fig.add_subplot(1, 2, 1)
ax.imshow(ref_image)

ax.set_title("Mitsuba (ref)")

ax = fig.add_subplot(1, 2, 2)
ax.imshow(image.squeeze().cpu().numpy())
ax.set_title("Pytorch3d")
# Out:
# Text(0.5, 1.0, 'Pytorch3d')

# %%
ORIG_SHAPE = (512, 512, 3)

body_estimation = Body('/home/ax/data/programs/pytorch-openpose/model/body_pose_model.pth', True)

# set defaults
body_estimation.imageToTest_padded_shape = ORIG_SHAPE
body_estimation.pad = [0, 0, 0, 0]

# Initialize a model using the renderer, mesh and reference image
model = Model(
    texTshirt=optmization_input["texTshirt"], 
    texOther=optmization_input["texOther"], 
    verticies=optmization_input["verticies"], 
    faces=optmization_input["faces"], 
    renderer=renderer,
    body_estimation=body_estimation
).to(device)

# Create an optimizer. Here we are using Adam and we pass in the parameters of the model
optimizer = torch.optim.Adam(model.parameters(), lr=0.05)
filename_output = "./texture_single_tshirt.gif"
run = wandb_init('torch3d')
writer = imageio.get_writer(filename_output, mode='I', duration=0.3)
# Out:
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/alexus/mts_tshirt_single" target="_blank">https://app.wandb.ai/alexus/mts_tshirt_single</a><br/>
#                 Run page: <a href="https://app.wandb.ai/alexus/mts_tshirt_single/runs/ywbwp20q" target="_blank">https://app.wandb.ai/alexus/mts_tshirt_single/runs/ywbwp20q</a><br/>

# %%
for i in tqdm(range(100)):
    optimizer.zero_grad()
    loss, cur_image = model()
    loss.backward()
    optimizer.step()
    wandb.log({'loss': loss.item()}, step=i)
    
    # Save outputs to create a GIF. 
    if i % 10 == 0:
        image = cur_image[0, ..., :3].detach().squeeze().cpu().numpy()
        image = np.clip(image, -1, 1)
        image = img_as_ubyte(image)
        writer.append_data(image)
    
writer.close()
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 0 < 91; dropping {'loss': 0.04955591633915901}.
#
#
#   1%|          | 1/100 [00:00<01:00,  1.64it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 1 < 91; dropping {'loss': 0.04954209923744202}.
#
#
#   2%|▏         | 2/100 [00:01<00:57,  1.71it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 2 < 91; dropping {'loss': 0.04954180121421814}.
#
#
#   3%|▎         | 3/100 [00:01<00:55,  1.75it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 3 < 91; dropping {'loss': 0.049524787813425064}.
#
#
#   4%|▍         | 4/100 [00:02<00:53,  1.78it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 4 < 91; dropping {'loss': 0.049517594277858734}.
#
#
#   5%|▌         | 5/100 [00:02<00:52,  1.80it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 5 < 91; dropping {'loss': 0.049514882266521454}.
#
#
#   6%|▌         | 6/100 [00:03<00:51,  1.82it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 6 < 91; dropping {'loss': 0.04950423166155815}.
#
#
#   7%|▋         | 7/100 [00:03<00:50,  1.84it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 7 < 91; dropping {'loss': 0.04949840158224106}.
#
#
#   8%|▊         | 8/100 [00:04<00:49,  1.85it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 8 < 91; dropping {'loss': 0.04949439316987991}.
#
#
#   9%|▉         | 9/100 [00:04<00:48,  1.86it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 9 < 91; dropping {'loss': 0.04949001967906952}.
#
#
#  10%|█         | 10/100 [00:05<00:48,  1.87it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 10 < 91; dropping {'loss': 0.049488674849271774}.
#
#
#  11%|█         | 11/100 [00:05<00:48,  1.85it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 11 < 91; dropping {'loss': 0.04947468265891075}.
#
#
#  12%|█▏        | 12/100 [00:06<00:47,  1.85it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 12 < 91; dropping {'loss': 0.04947428032755852}.
#
#
#  13%|█▎        | 13/100 [00:07<00:46,  1.86it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 13 < 91; dropping {'loss': 0.04946976900100708}.
#
#
#  14%|█▍        | 14/100 [00:07<00:46,  1.87it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 14 < 91; dropping {'loss': 0.049462802708148956}.
#
#
#  15%|█▌        | 15/100 [00:08<00:45,  1.87it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 15 < 91; dropping {'loss': 0.0494597889482975}.
#
#
#  16%|█▌        | 16/100 [00:08<00:44,  1.87it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 16 < 91; dropping {'loss': 0.04945160448551178}.
#
#
#  17%|█▋        | 17/100 [00:09<00:44,  1.88it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 17 < 91; dropping {'loss': 0.049442194402217865}.
#
#
#  18%|█▊        | 18/100 [00:09<00:43,  1.88it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 18 < 91; dropping {'loss': 0.049440354108810425}.
#
#
#  19%|█▉        | 19/100 [00:10<00:43,  1.88it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 19 < 91; dropping {'loss': 0.049456775188446045}.
#
#
#  20%|██        | 20/100 [00:10<00:42,  1.88it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 20 < 91; dropping {'loss': 0.04943794012069702}.
#
#
#  21%|██        | 21/100 [00:11<00:42,  1.85it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 21 < 91; dropping {'loss': 0.04943833500146866}.
#
#
#  22%|██▏       | 22/100 [00:11<00:41,  1.86it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 22 < 91; dropping {'loss': 0.049429330974817276}.
#
#
#  23%|██▎       | 23/100 [00:12<00:41,  1.87it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 23 < 91; dropping {'loss': 0.049434397369623184}.
#
#
#  24%|██▍       | 24/100 [00:12<00:40,  1.87it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 24 < 91; dropping {'loss': 0.04941990599036217}.
#
#
#  25%|██▌       | 25/100 [00:13<00:40,  1.87it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 25 < 91; dropping {'loss': 0.049418117851018906}.
#
#
#  26%|██▌       | 26/100 [00:13<00:39,  1.87it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 26 < 91; dropping {'loss': 0.04941374063491821}.
#
#
#  27%|██▋       | 27/100 [00:14<00:38,  1.88it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 27 < 91; dropping {'loss': 0.04941137135028839}.
#
#
#  28%|██▊       | 28/100 [00:15<00:38,  1.88it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 28 < 91; dropping {'loss': 0.049410346895456314}.
#
#
#  29%|██▉       | 29/100 [00:15<00:37,  1.88it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 29 < 91; dropping {'loss': 0.04941179230809212}.
#
#
#  30%|███       | 30/100 [00:16<00:37,  1.88it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 30 < 91; dropping {'loss': 0.04940168932080269}.
#
#
#  31%|███       | 31/100 [00:16<00:37,  1.86it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 31 < 91; dropping {'loss': 0.049400266259908676}.
#
#
#  32%|███▏      | 32/100 [00:17<00:36,  1.86it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 32 < 91; dropping {'loss': 0.04940110072493553}.
#
#
#  33%|███▎      | 33/100 [00:17<00:35,  1.86it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 33 < 91; dropping {'loss': 0.04939579591155052}.
#
#
#  34%|███▍      | 34/100 [00:18<00:35,  1.87it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 34 < 91; dropping {'loss': 0.049382247030735016}.
#
#
#  35%|███▌      | 35/100 [00:18<00:34,  1.88it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 35 < 91; dropping {'loss': 0.049387700855731964}.
#
#
#  36%|███▌      | 36/100 [00:19<00:34,  1.87it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 36 < 91; dropping {'loss': 0.04937456548213959}.
#
#
#  37%|███▋      | 37/100 [00:19<00:33,  1.88it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 37 < 91; dropping {'loss': 0.04937230050563812}.
#
#
#  38%|███▊      | 38/100 [00:20<00:33,  1.88it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 38 < 91; dropping {'loss': 0.049363650381565094}.
#
#
#  39%|███▉      | 39/100 [00:20<00:32,  1.88it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 39 < 91; dropping {'loss': 0.04935995116829872}.
#
#
#  40%|████      | 40/100 [00:21<00:31,  1.88it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 40 < 91; dropping {'loss': 0.049356576055288315}.
#
#
#  41%|████      | 41/100 [00:22<00:31,  1.85it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 41 < 91; dropping {'loss': 0.04936399683356285}.
#
#
#  42%|████▏     | 42/100 [00:22<00:31,  1.86it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 42 < 91; dropping {'loss': 0.0494212843477726}.
#
#
#  43%|████▎     | 43/100 [00:23<00:30,  1.87it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 43 < 91; dropping {'loss': 0.04938226938247681}.
#
#
#  44%|████▍     | 44/100 [00:23<00:29,  1.87it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 44 < 91; dropping {'loss': 0.04939020425081253}.
#
#
#  45%|████▌     | 45/100 [00:24<00:29,  1.87it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 45 < 91; dropping {'loss': 0.049378253519535065}.
#
#
#  46%|████▌     | 46/100 [00:24<00:28,  1.88it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 46 < 91; dropping {'loss': 0.0493755117058754}.
#
#
#  47%|████▋     | 47/100 [00:25<00:28,  1.88it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 47 < 91; dropping {'loss': 0.04937330633401871}.
#
#
#  48%|████▊     | 48/100 [00:25<00:27,  1.88it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 48 < 91; dropping {'loss': 0.04936009272933006}.
#
#
#  49%|████▉     | 49/100 [00:26<00:27,  1.88it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 49 < 91; dropping {'loss': 0.049357857555150986}.
#
#
#  50%|█████     | 50/100 [00:26<00:26,  1.88it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 50 < 91; dropping {'loss': 0.049347132444381714}.
#
#
#  51%|█████     | 51/100 [00:27<00:26,  1.85it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 51 < 91; dropping {'loss': 0.049341700971126556}.
#
#
#  52%|█████▏    | 52/100 [00:27<00:25,  1.86it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 52 < 91; dropping {'loss': 0.04933394491672516}.
#
#
#  53%|█████▎    | 53/100 [00:28<00:25,  1.87it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 53 < 91; dropping {'loss': 0.04932817071676254}.
#
#
#  54%|█████▍    | 54/100 [00:28<00:24,  1.87it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 54 < 91; dropping {'loss': 0.04932244494557381}.
#
#
#  55%|█████▌    | 55/100 [00:29<00:24,  1.87it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 55 < 91; dropping {'loss': 0.0493222139775753}.
#
#
#  56%|█████▌    | 56/100 [00:30<00:23,  1.87it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 56 < 91; dropping {'loss': 0.04932374134659767}.
#
#
#  57%|█████▋    | 57/100 [00:30<00:22,  1.88it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 57 < 91; dropping {'loss': 0.04932091012597084}.
#
#
#  58%|█████▊    | 58/100 [00:31<00:22,  1.88it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 58 < 91; dropping {'loss': 0.04930882900953293}.
#
#
#  59%|█████▉    | 59/100 [00:31<00:21,  1.87it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 59 < 91; dropping {'loss': 0.049302954226732254}.
#
#
#  60%|██████    | 60/100 [00:32<00:21,  1.87it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 60 < 91; dropping {'loss': 0.049302343279123306}.
#
#
#  61%|██████    | 61/100 [00:32<00:21,  1.85it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 61 < 91; dropping {'loss': 0.04930444806814194}.
#
#
#  62%|██████▏   | 62/100 [00:33<00:20,  1.85it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 62 < 91; dropping {'loss': 0.04933131858706474}.
#
#
#  63%|██████▎   | 63/100 [00:33<00:19,  1.86it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 63 < 91; dropping {'loss': 0.04930761083960533}.
#
#
#  64%|██████▍   | 64/100 [00:34<00:19,  1.87it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 64 < 91; dropping {'loss': 0.049305472522974014}.
#
#
#  65%|██████▌   | 65/100 [00:34<00:18,  1.87it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 65 < 91; dropping {'loss': 0.04929797723889351}.
#
#
#  66%|██████▌   | 66/100 [00:35<00:18,  1.87it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 66 < 91; dropping {'loss': 0.04929279908537865}.
#
#
#  67%|██████▋   | 67/100 [00:35<00:17,  1.88it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 67 < 91; dropping {'loss': 0.04929516837000847}.
#
#
#  68%|██████▊   | 68/100 [00:36<00:17,  1.87it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 68 < 91; dropping {'loss': 0.049283310770988464}.
#
#
#  69%|██████▉   | 69/100 [00:36<00:16,  1.88it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 69 < 91; dropping {'loss': 0.04928010329604149}.
#
#
#  70%|███████   | 70/100 [00:37<00:15,  1.88it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 70 < 91; dropping {'loss': 0.04927239567041397}.
#
#
#  71%|███████   | 71/100 [00:38<00:15,  1.86it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 71 < 91; dropping {'loss': 0.04927065968513489}.
#
#
#  72%|███████▏  | 72/100 [00:38<00:15,  1.86it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 72 < 91; dropping {'loss': 0.04927673190832138}.
#
#
#  73%|███████▎  | 73/100 [00:39<00:14,  1.87it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 73 < 91; dropping {'loss': 0.04927560314536095}.
#
#
#  74%|███████▍  | 74/100 [00:39<00:13,  1.87it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 74 < 91; dropping {'loss': 0.049278903752565384}.
#
#
#  75%|███████▌  | 75/100 [00:40<00:13,  1.88it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 75 < 91; dropping {'loss': 0.04926557093858719}.
#
#
#  76%|███████▌  | 76/100 [00:40<00:12,  1.88it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 76 < 91; dropping {'loss': 0.04926792159676552}.
#
#
#  77%|███████▋  | 77/100 [00:41<00:12,  1.88it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 77 < 91; dropping {'loss': 0.04926154762506485}.
#
#
#  78%|███████▊  | 78/100 [00:41<00:11,  1.88it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 78 < 91; dropping {'loss': 0.0492541566491127}.
#
#
#  79%|███████▉  | 79/100 [00:42<00:11,  1.88it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 79 < 91; dropping {'loss': 0.04925287887454033}.
#
#
#  80%|████████  | 80/100 [00:42<00:10,  1.88it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 80 < 91; dropping {'loss': 0.04924675449728966}.
#
#
#  81%|████████  | 81/100 [00:43<00:10,  1.86it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 81 < 91; dropping {'loss': 0.04924265667796135}.
#
#
#  82%|████████▏ | 82/100 [00:43<00:09,  1.86it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 82 < 91; dropping {'loss': 0.049239810556173325}.
#
#
#  83%|████████▎ | 83/100 [00:44<00:09,  1.87it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 83 < 91; dropping {'loss': 0.04923904314637184}.
#
#
#  84%|████████▍ | 84/100 [00:44<00:08,  1.87it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 84 < 91; dropping {'loss': 0.04924299195408821}.
#
#
#  85%|████████▌ | 85/100 [00:45<00:07,  1.88it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 85 < 91; dropping {'loss': 0.049258191138505936}.
#
#
#  86%|████████▌ | 86/100 [00:46<00:07,  1.88it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 86 < 91; dropping {'loss': 0.0492367297410965}.
#
#
#  87%|████████▋ | 87/100 [00:46<00:06,  1.88it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 87 < 91; dropping {'loss': 0.04924285411834717}.
#
#
#  88%|████████▊ | 88/100 [00:47<00:06,  1.88it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 88 < 91; dropping {'loss': 0.0492430254817009}.
#
#
#  89%|████████▉ | 89/100 [00:47<00:05,  1.88it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 89 < 91; dropping {'loss': 0.04922861605882645}.
#
#
#  90%|█████████ | 90/100 [00:48<00:05,  1.88it/s]wandb: WARNING Adding to old History rows isn't currently supported.  Step 90 < 91; dropping {'loss': 0.04922870174050331}.
#
#
#  91%|█████████ | 91/100 [00:48<00:04,  1.86it/s]
#
#  92%|█████████▏| 92/100 [00:49<00:04,  1.86it/s]
#
#  93%|█████████▎| 93/100 [00:52<00:09,  1.30s/it]
#
#  94%|█████████▍| 94/100 [00:52<00:06,  1.09s/it]
#
#  95%|█████████▌| 95/100 [00:53<00:04,  1.08it/s]
#
#  96%|█████████▌| 96/100 [00:54<00:03,  1.23it/s]
#
#  97%|█████████▋| 97/100 [00:54<00:02,  1.36it/s]
#
#  98%|█████████▊| 98/100 [00:55<00:01,  1.45it/s]
#
#  99%|█████████▉| 99/100 [00:55<00:00,  1.53it/s]
#
# 100%|██████████| 100/100 [00:56<00:00,  1.78it/s]

# %% [raw]
# ![SegmentLocal](texture_single_tshirt.gif "segment")

# %%
(canvas_orig, 
 candidate_orig,
 subset_orig,
 heatmap_avg_orig,
 paf_avg_orig) = get_body_image_from_mesh(mesh, body_estimation, renderer)

(canvas_noise, 
 candidate_noise,
 subset_noise,
 heatmap_avg_noise,
 paf_avg_noise) = get_body_image_from_mesh(model.cur_mesh, body_estimation, renderer)

# %%
fig = plt.figure(figsize=(20, 10))
ax = fig.add_subplot(1, 2, 1)
ax.imshow(canvas_orig)
ax.set_title('Original')

ax = fig.add_subplot(1, 2, 2)
ax.imshow(canvas_noise)
ax.set_title('Adv')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Text(0.5, 1.0, 'Adv')
